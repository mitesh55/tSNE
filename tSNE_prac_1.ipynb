# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
titanic = pd.read_csv(r'Titanic.csv')
titanic.head()
# Out:
#   Class Gender    Age Survived
# 0   3rd   Male  Child       No
# 1   3rd   Male  Child       No
# 2   3rd   Male  Child       No
# 3   3rd   Male  Child       No
# 4   3rd   Male  Child       No

# %%
df = pd.get_dummies(titanic)

# %%
frequent_items = apriori(df, min_support=0.1, use_colnames=True)
frequent_items
# Out:
#      support                                           itemsets
# 0   0.147660                                        (Class_1st)
# 1   0.129487                                        (Class_2nd)
# 2   0.320763                                        (Class_3rd)
# 3   0.402090                                       (Class_Crew)
# 4   0.213539                                    (Gender_Female)
# 5   0.786461                                      (Gender_Male)
# 6   0.950477                                        (Age_Adult)
# 7   0.676965                                      (Survived_No)
# 8   0.323035                                     (Survived_Yes)
# 9   0.144934                             (Age_Adult, Class_1st)
# 10  0.118582                             (Age_Adult, Class_2nd)
# 11  0.231713                           (Class_3rd, Gender_Male)
# 12  0.284871                             (Age_Adult, Class_3rd)
# 13  0.239891                           (Survived_No, Class_3rd)
# 14  0.391640                          (Class_Crew, Gender_Male)
# 15  0.402090                            (Age_Adult, Class_Crew)
# 16  0.305770                          (Survived_No, Class_Crew)
# 17  0.193094                         (Age_Adult, Gender_Female)
# 18  0.156293                      (Survived_Yes, Gender_Female)
# 19  0.757383                           (Age_Adult, Gender_Male)
# 20  0.619718                         (Survived_No, Gender_Male)
# 21  0.166742                        (Gender_Male, Survived_Yes)
# 22  0.653339                           (Age_Adult, Survived_No)
# 23  0.297138                          (Age_Adult, Survived_Yes)
# 24  0.209905                (Age_Adult, Class_3rd, Gender_Male)
# 25  0.191731              (Survived_No, Class_3rd, Gender_Male)
# 26  0.216265                (Age_Adult, Survived_No, Class_3rd)
# 27  0.391640               (Age_Adult, Class_Crew, Gender_Male)
# 28  0.304407             (Survived_No, Class_Crew, Gender_Male)
# 29  0.305770               (Age_Adult, Survived_No, Class_Crew)
# 30  0.143571           (Age_Adult, Survived_Yes, Gender_Female)
# 31  0.603816              (Age_Adult, Survived_No, Gender_Male)
# 32  0.153567             (Age_Adult, Gender_Male, Survived_Yes)
# 33  0.175829   (Age_Adult, Survived_No, Class_3rd, Gender_Male)
# 34  0.304407  (Age_Adult, Survived_No, Class_Crew, Gender_Male)

# %%
rules = association_rules(frequent_items, metric='lift', min_threshold=0.7)
rules
# Out:
#                    antecedents                             consequents  \
# 0                  (Age_Adult)                             (Class_1st)
# 1                  (Class_1st)                             (Age_Adult)
# 2                  (Age_Adult)                             (Class_2nd)
# 3                  (Class_2nd)                             (Age_Adult)
# 4                  (Class_3rd)                           (Gender_Male)
# ..                         ...                                     ...
# 101  (Class_Crew, Gender_Male)                (Age_Adult, Survived_No)
# 102                (Age_Adult)  (Survived_No, Class_Crew, Gender_Male)
# 103              (Survived_No)    (Age_Adult, Class_Crew, Gender_Male)
# 104               (Class_Crew)   (Age_Adult, Survived_No, Gender_Male)
# 105              (Gender_Male)    (Age_Adult, Survived_No, Class_Crew)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.950477            0.147660  0.144934    0.152486  1.032680
# 1              0.147660            0.950477  0.144934    0.981538  1.032680
# 2              0.950477            0.129487  0.118582    0.124761  0.963505
# 3              0.129487            0.950477  0.118582    0.915789  0.963505
# 4              0.320763            0.786461  0.231713    0.722380  0.918520
# ..                  ...                 ...       ...         ...       ...
# 101            0.391640            0.653339  0.304407    0.777262  1.189676
# 102            0.950477            0.304407  0.304407    0.320268  1.052103
# 103            0.676965            0.391640  0.304407    0.449664  1.148157
# 104            0.402090            0.603816  0.304407    0.757062  1.253795
# 105            0.786461            0.305770  0.304407    0.387060  1.265851
#
#      leverage  conviction
# 0    0.004587    1.005694
# 1    0.004587    2.682493
# 2   -0.004492    0.994601
# 3   -0.004492    0.588085
# 4   -0.020555    0.769177
# ..        ...         ...
# 101  0.048533    1.556362
# 102  0.015075    1.023334
# 103  0.039280    1.105434
# 104  0.061619    1.630802
# 105  0.063931    1.132622
#
# [106 rows x 9 columns]

# %%
rules.so
